# %%
from src.fitterroutines import Image
# %matplotlib inline

# %%
q = Image(source="file",imagepath="/Users/oleksiy/Desktop/PythonCode/beamFitter/ExampleImages/210 mA/91.bmp")
q.fitandprint_axis(0)
q.fitandplot_axis(0)
q.fitandprint_axis(1)
q.fitandplot_axis(1)
q.fitandprint_2D()
q.fitandplot_2D()
# Out:
# I_zero = 5265.24872509
# r_zero = 1.64509170233 mm
# omega_zero = 0.29713848645 mm
# backgr = 21489.6260339
# The sizes are in mm
# I_zero = 5271.03498271
# r_zero = 4.68257502732 mm
# omega_zero = 0.318797033094 mm
# backgr = 17169.0074569
# Not including rotation
# The sizes are in mm
# I_zero = 69.0963572776
# x_zero = 128.386251143
# y_zero = 118.161212881
# omegaX_zero = 59.8854607038
# omegaY_zero = 59.3213177213
# theta_rot = 3.06277835233
# backgr = 17.2805546425
